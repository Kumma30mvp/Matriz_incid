# %% [markdown]
# # Matriz de incidencia

# %%
# Modulos
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 1- Definir el stoplist

# %%
with open("stoplist.txt") as file:
    stoplist = [line.strip() for line in file]
stoplist += ['?', '-', '.', ':', ',']

# %% [markdown]
# ## 2-  Tokenizar y eliminar stopwords

# %%
# Importar NLTK y descargar el conjunto de stopwords
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# Obtener el conjunto de stopwords en el idioma deseado (por ejemplo, español)
stoplist = set(stopwords.words('spanish'))

# Función para preprocesar el documento, eliminando las stopwords
def preprocesamiento(doc, stoplist):
    tokens = word_tokenize(doc)
    words = [word.lower() for word in tokens if word.lower() not in stoplist]
    return words

# Función para leer el contenido de los archivos de texto (libros)
def leer_archivos(libros):
    list_docs = []
    for libro in libros:
        with open(libro, "r") as file:
            list_docs.append(file.read())
    return list_docs

# Llamar a las funciones para obtener la lista de documentos
libros = ["libro1.txt", "libro2.txt", "libro3.txt", "libro4.txt", "libro5.txt", "libro6.txt"]
list_docs = leer_archivos(libros)

# Preprocesar los documentos para eliminar stopwords
list_docs_procesados = [preprocesamiento(doc, stoplist) for doc in list_docs]

# Ahora list_docs_procesados contiene los documentos procesados sin stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 3- Construir la matriz de incidencia

# %%
def construir_matriz(list_docs, stoplist):
    vocabulario = set()
    for doc in list_docs:
        palabras = preprocesamiento(doc, stoplist)
        vocabulario.update(palabras)
    vocabulario = sorted(list(vocabulario))
    
    matriz = np.zeros((len(list_docs), len(vocabulario)), dtype=int)
    
    for i, doc in enumerate(list_docs):
        palabras = preprocesamiento(doc, stoplist)
        contador_palabras = Counter(palabras)
        for j, palabra in enumerate(vocabulario):
            matriz[i][j] = contador_palabras[palabra]
    
    return matriz, vocabulario

# %% [markdown]
# ## 4- Aplicar consultas booleanas

# %%
def M(word):
    pass

def AND(A, B):
    pass

def OR(A, B):
    pass

def NOT(A):
    pass

Query1 = AND(M("anillo"), M("frodo"))
print("anillo AND frodo: ", Query1)
Query2 = OR(M("anillo"), M("frodo"))
print("anillo OR frodo: ", Query1)
# definir mas queries
# Out:
# anillo AND frodo:  None
# anillo OR frodo:  None

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b824a2a4-ec75-4e0c-9c8d-ae3f8e552746' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
